# %% [markdown]
# # Data preporocessing

# %% [markdown]
# # Description
# This is a simulated dataset exploring how lifestyle habits affect academic performance in students. With 1,000 synthetic student records and 15+ features including study hours, sleep patterns, social media usage, diet quality, mental health, and final exam scores, it’s perfect for ML projects, regression analysis, clustering, and data viz. Created using realistic patterns for educational practice.
#
# Ever wondered how much Netflix, sleep, or TikTok scrolling affects your grades? 👀 This dataset simulates 1,000 students' daily habits—from study time to mental health—and compares them to final exam scores. It's like spying on your GPA through the lens of lifestyle. Perfect for EDA, ML practice, or just vibing with data while pretending to be productive.

# %%
import matplotlib.pyplot as plt 
import seaborn as sns 
color = sns.color_palette()

import numpy as np
import pandas as pd

# %% [markdown]
# # Reading Data

# %%
data = pd.read_csv('student_habits_performance.csv')
data.head()
# Out:
#   student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0      S1000   23  Female                  0.0                 1.2
# 1      S1001   20  Female                  6.9                 2.8
# 2      S1002   21    Male                  1.4                 3.1
# 3      S1003   23  Female                  1.0                 3.9
# 4      S1004   19  Female                  5.0                 4.4
#
#    netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0            1.1            No                   85.0          8.0
# 1            2.3            No                   97.3          4.6
# 2            1.3            No                   94.8          8.0
# 3            1.0            No                   71.0          9.2
# 4            0.5            No                   90.9          4.9
#
#   diet_quality  exercise_frequency parental_education_level internet_quality  \
# 0         Fair                   6                   Master          Average
# ...

# %%
data.head(2)
# Out:
#   student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0      S1000   23  Female                  0.0                 1.2
# 1      S1001   20  Female                  6.9                 2.8
#
#    netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0            1.1            No                   85.0          8.0
# 1            2.3            No                   97.3          4.6
#
#   diet_quality  exercise_frequency parental_education_level internet_quality  \
# 0         Fair                   6                   Master          Average
# 1         Good                   6              High School          Average
#
#    mental_health_rating extracurricular_participation  exam_score
# 0                     8                           Yes        56.2
# 1                     8                            No       100.0

# %%
data.head(30)
# Out:
#    student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0       S1000   23  Female                  0.0                 1.2
# 1       S1001   20  Female                  6.9                 2.8
# 2       S1002   21    Male                  1.4                 3.1
# 3       S1003   23  Female                  1.0                 3.9
# 4       S1004   19  Female                  5.0                 4.4
# 5       S1005   24    Male                  7.2                 1.3
# 6       S1006   21  Female                  5.6                 1.5
# 7       S1007   21  Female                  4.3                 1.0
# 8       S1008   23  Female                  4.4                 2.2
# 9       S1009   18  Female                  4.8                 3.1
# 10      S1010   19  Female                  4.6                 3.7
# 11      S1011   23    Male                  3.9                 2.4
# 12      S1012   19  Female                  3.7                 2.1
# ...

# %%
data.tail()
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 995      S1995   21  Female                  2.6                 0.5
# 996      S1996   17  Female                  2.9                 1.0
# 997      S1997   20    Male                  3.0                 2.6
# 998      S1998   24    Male                  5.4                 4.1
# 999      S1999   19  Female                  4.3                 2.9
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 995            1.6            No                   77.0          7.5
# 996            2.4           Yes                   86.0          6.8
# 997            1.3            No                   61.9          6.5
# 998            1.1           Yes                  100.0          7.6
# 999            1.9            No                   89.4          7.1
#
#     diet_quality  exercise_frequency parental_education_level  \
# 995         Fair                   2              High School
# ...

# %%
data.shape
# Out:
# (1000, 16)

# %%
data.tail(20)
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 980      S1980   20  Female                  3.7                 3.5
# 981      S1981   24    Male                  3.6                 0.0
# 982      S1982   20  Female                  3.8                 2.4
# 983      S1983   21    Male                  3.9                 1.8
# 984      S1984   24    Male                  3.2                 3.0
# 985      S1985   18    Male                  5.7                 3.1
# 986      S1986   20    Male                  1.1                 1.7
# 987      S1987   20  Female                  2.3                 1.6
# 988      S1988   18    Male                  3.3                 2.4
# 989      S1989   24    Male                  1.0                 1.4
# 990      S1990   18    Male                  3.2                 3.5
# 991      S1991   20    Male                  6.0                 2.1
# 992      S1992   18    Male                  3.5                 0.0
# ...

# %%
data.sample()
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 685      S1685   22  Female                  2.0                 1.2
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 685            2.7            No                   67.2          6.7
#
#     diet_quality  exercise_frequency parental_education_level  \
# 685         Poor                   6                 Bachelor
#
#     internet_quality  mental_health_rating extracurricular_participation  \
# 685          Average                     8                            No
#
#      exam_score
# 685        55.4

# %%
data.sample(30)
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 328      S1328   24  Female                  1.2                 2.5
# 880      S1880   21    Male                  2.5                 3.2
# 412      S1412   22  Female                  3.9                 2.1
# 223      S1223   20  Female                  2.6                 2.4
# 965      S1965   17    Male                  4.3                 3.4
# 323      S1323   18    Male                  2.9                 1.6
# 179      S1179   19  Female                  3.8                 1.7
# 741      S1741   22  Female                  3.0                 2.0
# 553      S1553   20  Female                  4.8                 0.8
# 615      S1615   19  Female                  1.5                 2.2
# 935      S1935   17    Male                  3.4                 4.0
# 401      S1401   20    Male                  2.4                 2.6
# 1        S1001   20  Female                  6.9                 2.8
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   student_id                     1000 non-null   object
#  1   age                            1000 non-null   int64
#  2   gender                         1000 non-null   object
#  3   study_hours_per_day            1000 non-null   float64
#  4   social_media_hours             1000 non-null   float64
#  5   netflix_hours                  1000 non-null   float64
#  6   part_time_job                  1000 non-null   object
#  7   attendance_percentage          1000 non-null   float64
#  8   sleep_hours                    1000 non-null   float64
#  9   diet_quality                   1000 non-null   object
#  10  exercise_frequency             1000 non-null   int64
#  11  parental_education_level       909 non-null    object
# ...

# %%
data.describe()
# Out:
#              age  study_hours_per_day  social_media_hours  netflix_hours  \
# count  1000.0000           1000.00000         1000.000000    1000.000000
# mean     20.4980              3.55010            2.505500       1.819700
# std       2.3081              1.46889            1.172422       1.075118
# min      17.0000              0.00000            0.000000       0.000000
# 25%      18.7500              2.60000            1.700000       1.000000
# 50%      20.0000              3.50000            2.500000       1.800000
# 75%      23.0000              4.50000            3.300000       2.525000
# max      24.0000              8.30000            7.200000       5.400000
#
#        attendance_percentage  sleep_hours  exercise_frequency  \
# count            1000.000000  1000.000000         1000.000000
# mean               84.131700     6.470100            3.042000
# std                 9.399246     1.226377            2.025423
# ...

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# Handling Missing Values
# -
# - Imputation: Filling missing values with mean.

# %%
import pandas as pd

# %%
data.isnull().sum()
# Out:
# student_id                        0
# age                               0
# gender                            0
# study_hours_per_day               0
# social_media_hours                0
# netflix_hours                     0
# part_time_job                     0
# attendance_percentage             0
# sleep_hours                       0
# diet_quality                      0
# exercise_frequency                0
# parental_education_level         91
# internet_quality                  0
# mental_health_rating              0
# extracurricular_participation     0
# exam_score                        0
# dtype: int64

# %%
import pandas as pd
import numpy as np

numeric_cols = data.select_dtypes(include=[np.number])
non_numeric_cols = data.select_dtypes(exclude=[np.number])

numeric_cols.fillna(numeric_cols.mean(), inplace=True)   # Numerical features

data = pd.concat([numeric_cols, non_numeric_cols], axis=1)

missing_values = data.isnull().sum()
print(missing_values)
# Out:
# age                               0
# study_hours_per_day               0
# social_media_hours                0
# netflix_hours                     0
# attendance_percentage             0
# sleep_hours                       0
# exercise_frequency                0
# mental_health_rating              0
# exam_score                        0
# student_id                        0
# gender                            0
# part_time_job                     0
# diet_quality                      0
# parental_education_level         91
# internet_quality                  0
# extracurricular_participation     0
# dtype: int64

# %%
import pandas as pd
import numpy as np

for col in data.select_dtypes(include=[np.number]).columns:
    data[col] = data[col].fillna(data[col].mean())

for col in data.select_dtypes(exclude=[np.number]).columns:
    data[col] = data[col].fillna(data[col].mode()[0])

missing_values = data.isnull().sum()
print(missing_values)
# Out:
# age                              0
# study_hours_per_day              0
# social_media_hours               0
# netflix_hours                    0
# attendance_percentage            0
# sleep_hours                      0
# exercise_frequency               0
# mental_health_rating             0
# exam_score                       0
# student_id                       0
# gender                           0
# part_time_job                    0
# diet_quality                     0
# parental_education_level         0
# internet_quality                 0
# extracurricular_participation    0
# dtype: int64

# %%
data.shape
# Out:
# (1000, 16)

# %% [markdown]
# # Removal: Deleting rows with missing values.

# %%
data.isnull().sum()
# Out:
# age                              0
# study_hours_per_day              0
# social_media_hours               0
# netflix_hours                    0
# attendance_percentage            0
# sleep_hours                      0
# exercise_frequency               0
# mental_health_rating             0
# exam_score                       0
# student_id                       0
# gender                           0
# part_time_job                    0
# diet_quality                     0
# parental_education_level         0
# internet_quality                 0
# extracurricular_participation    0
# dtype: int64

# %%
data.shape
# Out:
# (1000, 16)

# %%
data.dropna(inplace=True)

missing_values = data.isnull().sum()
print(missing_values)
# Out:
# age                              0
# study_hours_per_day              0
# social_media_hours               0
# netflix_hours                    0
# attendance_percentage            0
# sleep_hours                      0
# exercise_frequency               0
# mental_health_rating             0
# exam_score                       0
# student_id                       0
# gender                           0
# part_time_job                    0
# diet_quality                     0
# parental_education_level         0
# internet_quality                 0
# extracurricular_participation    0
# dtype: int64

# %%
data.shape
# Out:
# (1000, 16)

# %% [markdown]
# Removing Duplicates
# -

# %%
data.shape
# Out:
# (1000, 16)

# %%
data.drop_duplicates(inplace=True)
data.shape
# Out:
# (1000, 16)

# %% [markdown]
# # Outlier Detection and Removal

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data.describe()
# Out:
#              age  study_hours_per_day  social_media_hours  netflix_hours  \
# count  1000.0000           1000.00000         1000.000000    1000.000000
# mean     20.4980              3.55010            2.505500       1.819700
# std       2.3081              1.46889            1.172422       1.075118
# min      17.0000              0.00000            0.000000       0.000000
# 25%      18.7500              2.60000            1.700000       1.000000
# 50%      20.0000              3.50000            2.500000       1.800000
# 75%      23.0000              4.50000            3.300000       2.525000
# max      24.0000              8.30000            7.200000       5.400000
#
#        attendance_percentage  sleep_hours  exercise_frequency  \
# count            1000.000000  1000.000000         1000.000000
# mean               84.131700     6.470100            3.042000
# std                 9.399246     1.226377            2.025423
# ...

# %%
0.25-1.5*0.5
# Out:
# -0.5

# %%
0.75 + 1.5 * 0.5
# Out:
# 1.5

# %%
numeric_cols = data.select_dtypes(include=[np.number])

Q1 = numeric_cols.quantile(0.25)
Q3 = numeric_cols.quantile(0.75)
IQR = Q3 - Q1

data_cleaned = data[~((numeric_cols < (Q1 - 1.5 * IQR)) | (numeric_cols > (Q3 + 1.5 * IQR))).any(axis=1)]

plt.figure(figsize=(20, 6))

plt.subplot(1, 2, 1)
numeric_cols.boxplot()
plt.title("Before Outlier Removal")

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(20, 6))

plt.subplot(1, 2, 2)
data_cleaned.select_dtypes(include=[np.number]).boxplot()
plt.title("After Outlier Removal")

plt.tight_layout()
plt.show()

# %%
data_cleaned.shape
# Out:
# (977, 16)

# %%
data_cleaned.head()
# Out:
#    age  study_hours_per_day  social_media_hours  netflix_hours  \
# 0   23                  0.0                 1.2            1.1
# 1   20                  6.9                 2.8            2.3
# 2   21                  1.4                 3.1            1.3
# 3   23                  1.0                 3.9            1.0
# 4   19                  5.0                 4.4            0.5
#
#    attendance_percentage  sleep_hours  exercise_frequency  \
# 0                   85.0          8.0                   6
# 1                   97.3          4.6                   6
# 2                   94.8          8.0                   1
# 3                   71.0          9.2                   4
# 4                   90.9          4.9                   3
#
#    mental_health_rating  exam_score student_id  gender part_time_job  \
# 0                     8        56.2      S1000  Female            No
# 1                     8       100.0      S1001  Female            No
# ...

# %% [markdown]
# # Data Transformation

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler

numeric_cols = data.select_dtypes(include=[np.number])
non_numeric_cols = data.select_dtypes(exclude=[np.number])

scaler = MinMaxScaler()
scaled_numeric_data = scaler.fit_transform(numeric_cols)

scaled_numeric_df = pd.DataFrame(scaled_numeric_data, columns=numeric_cols.columns)

scaled_data = pd.concat([scaled_numeric_df, non_numeric_cols.reset_index(drop=True)], axis=1)

print(scaled_data.shape)
print()
print('*' * 60)
scaled_data.head()
# Out:
# (1000, 16)
#
# ************************************************************
#         age  study_hours_per_day  social_media_hours  netflix_hours  \
# 0  0.857143             0.000000            0.166667       0.203704
# 1  0.428571             0.831325            0.388889       0.425926
# 2  0.571429             0.168675            0.430556       0.240741
# 3  0.857143             0.120482            0.541667       0.185185
# 4  0.285714             0.602410            0.611111       0.092593
#
#    attendance_percentage  sleep_hours  exercise_frequency  \
# 0               0.659091     0.705882            1.000000
# 1               0.938636     0.205882            1.000000
# 2               0.881818     0.705882            0.166667
# 3               0.340909     0.882353            0.666667
# 4               0.793182     0.250000            0.500000
#
#    mental_health_rating  exam_score student_id  gender part_time_job  \
# ...

# %% [markdown]
# # Standardization

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler

numeric_cols = data.select_dtypes(include=[np.number])
non_numeric_cols = data.select_dtypes(exclude=[np.number])

scaler = StandardScaler()
scaled_numeric_data = scaler.fit_transform(numeric_cols)

scaled_numeric_df = pd.DataFrame(scaled_numeric_data, columns=numeric_cols.columns)

scaled_data = pd.concat([scaled_numeric_df, non_numeric_cols.reset_index(drop=True)], axis=1)

print(scaled_data.shape)
print()
print('*' * 60)
scaled_data.head()
# Out:
# (1000, 16)
#
# ************************************************************
#         age  study_hours_per_day  social_media_hours  netflix_hours  \
# 0  1.084551            -2.418068           -1.114064      -0.669750
# 1 -0.215870             2.281707            0.251315       0.446965
# 2  0.217604            -1.464491            0.507324      -0.483631
# 3  1.084551            -1.736942            1.190013      -0.762810
# 4 -0.649344             0.987566            1.616694      -1.228108
#
#    attendance_percentage  sleep_hours  exercise_frequency  \
# 0               0.092426     1.248120            1.461166
# 1               1.401696    -1.525661            1.461166
# 2               1.135584     1.248120           -1.008689
# 3              -1.397800     2.227102            0.473224
# 4               0.720450    -1.280916           -0.020747
#
#    mental_health_rating  exam_score student_id  gender part_time_job  \
# ...

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler

data.head(2)
# Out:
#    age  study_hours_per_day  social_media_hours  netflix_hours  \
# 0   23                  0.0                 1.2            1.1
# 1   20                  6.9                 2.8            2.3
#
#    attendance_percentage  sleep_hours  exercise_frequency  \
# 0                   85.0          8.0                   6
# 1                   97.3          4.6                   6
#
#    mental_health_rating  exam_score student_id  gender part_time_job  \
# 0                     8        56.2      S1000  Female            No
# 1                     8       100.0      S1001  Female            No
#
#   diet_quality parental_education_level internet_quality  \
# 0         Fair                   Master          Average
# 1         Good              High School          Average
#
#   extracurricular_participation
# 0                           Yes
# 1                            No

# %%
data["age"].unique()
# Out:
# array([23, 20, 21, 19, 24, 18, 22, 17], dtype=int64)

# %%
data.age.unique()
# Out:
# array([23, 20, 21, 19, 24, 18, 22, 17], dtype=int64)

# %%
data.age.unique()
# Out:
# array([23, 20, 21, 19, 24, 18, 22, 17], dtype=int64)

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler

cat_features = [feature for feature in data.columns if data[feature].dtype == 'O']

data1 = pd.get_dummies(cat_features)
data1
# Out:
#    diet_quality  extracurricular_participation  gender  internet_quality  \
# 0         False                          False   False             False
# 1         False                          False    True             False
# 2         False                          False   False             False
# 3          True                          False   False             False
# 4         False                          False   False             False
# 5         False                          False   False              True
# 6         False                           True   False             False
#
#    parental_education_level  part_time_job  student_id
# 0                     False          False        True
# 1                     False          False       False
# 2                     False           True       False
# 3                     False          False       False
# 4                      True          False       False
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   diet_quality                   7 non-null      bool
#  1   extracurricular_participation  7 non-null      bool
#  2   gender                         7 non-null      bool
#  3   internet_quality               7 non-null      bool
#  4   parental_education_level       7 non-null      bool
#  5   part_time_job                  7 non-null      bool
#  6   student_id                     7 non-null      bool
# dtypes: bool(7)
# memory usage: 181.0 bytes

# %%
cat_features
# Out:
# ['student_id',
#  'gender',
#  'part_time_job',
#  'diet_quality',
#  'parental_education_level',
#  'internet_quality',
#  'extracurricular_participation']

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler

cat_features = [feature for feature in data.columns if data[feature].dtype == 'O']

data1 = pd.get_dummies(data, columns=cat_features)

scaled_data = pd.concat([data, data1], axis=1)

print(scaled_data.shape)
print()
print('*' * 70)

scaled_data.head()
# Out:
# (1000, 1041)
#
# **********************************************************************
#    age  study_hours_per_day  social_media_hours  netflix_hours  \
# 0   23                  0.0                 1.2            1.1
# 1   20                  6.9                 2.8            2.3
# 2   21                  1.4                 3.1            1.3
# 3   23                  1.0                 3.9            1.0
# 4   19                  5.0                 4.4            0.5
#
#    attendance_percentage  sleep_hours  exercise_frequency  \
# 0                   85.0          8.0                   6
# 1                   97.3          4.6                   6
# 2                   94.8          8.0                   1
# 3                   71.0          9.2                   4
# 4                   90.9          4.9                   3
#
#    mental_health_rating  exam_score student_id  ... diet_quality_Good  \
# 0                     8        56.2      S1000  ...             False
# ...

# %%
data.columns
# Out:
# Index(['age', 'study_hours_per_day', 'social_media_hours', 'netflix_hours',
#        'attendance_percentage', 'sleep_hours', 'exercise_frequency',
#        'mental_health_rating', 'exam_score', 'student_id', 'gender',
#        'part_time_job', 'diet_quality', 'parental_education_level',
#        'internet_quality', 'extracurricular_participation'],
#       dtype='object')

# %%
scaled_data.columns
# Out:
# Index(['age', 'study_hours_per_day', 'social_media_hours', 'netflix_hours',
#        'attendance_percentage', 'sleep_hours', 'exercise_frequency',
#        'mental_health_rating', 'exam_score', 'student_id',
#        ...
#        'diet_quality_Good', 'diet_quality_Poor',
#        'parental_education_level_Bachelor',
#        'parental_education_level_High School',
#        'parental_education_level_Master', 'internet_quality_Average',
#        'internet_quality_Good', 'internet_quality_Poor',
#        'extracurricular_participation_No',
#        'extracurricular_participation_Yes'],
#       dtype='object', length=1041)

# %%
data1.head()
# Out:
#    age  study_hours_per_day  social_media_hours  netflix_hours  \
# 0   23                  0.0                 1.2            1.1
# 1   20                  6.9                 2.8            2.3
# 2   21                  1.4                 3.1            1.3
# 3   23                  1.0                 3.9            1.0
# 4   19                  5.0                 4.4            0.5
#
#    attendance_percentage  sleep_hours  exercise_frequency  \
# 0                   85.0          8.0                   6
# 1                   97.3          4.6                   6
# 2                   94.8          8.0                   1
# 3                   71.0          9.2                   4
# 4                   90.9          4.9                   3
#
#    mental_health_rating  exam_score  student_id_S1000  ...  diet_quality_Good  \
# 0                     8        56.2              True  ...              False
# ...

# %% [markdown]
# # Data reduction

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

data.fillna(data.mean(numeric_only=True), inplace=True)

cat_features = [feature for feature in data.columns if data[feature].dtype == 'O']
numeric_features = [feature for feature in data.columns if data[feature].dtype != 'O']

data = pd.get_dummies(data, columns=cat_features)

scaler = StandardScaler()
data[numeric_features] = scaler.fit_transform(data[numeric_features].values)

pca = PCA(n_components=15)
data_pca = pca.fit_transform(data)

print(data_pca.shape)
print(data_pca[:5])

plt.figure(figsize=(14, 6))

if len(numeric_features) >= 2:
    plt.subplot(1, 2, 1)
    plt.scatter(data[numeric_features[0]], data[numeric_features[1]], alpha=0.5)
    plt.title('Original Data')
    plt.xlabel(numeric_features[0])
    plt.ylabel(numeric_features[1])
else:
    print("Error: Not enough numeric features to plot.")

plt.subplot(1, 2, 2)
plt.scatter(data_pca[:, 0], data_pca[:, 1], alpha=0.5)
plt.title('PCA Transformed Data')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')

plt.tight_layout()
plt.show()
# Out:
# (1000, 15)
# [[-1.3461333  -2.40838518  0.71173116  1.57961539  0.31836251 -0.89607988
#   -0.78177822  1.09913142  0.90417288 -0.62677094  0.31991742 -0.88023976
#    0.59744985  0.07958593 -0.03390718]
#  [ 2.9885109   0.64790718 -1.05052554  0.06872077  0.87011728  1.55594947
#    1.05735368  1.15990289  0.64576843 -0.03548741  0.97653689  0.55369992
#   -0.45562913  0.43521207 -0.25338008]
#  [-2.69384051  1.1353258   1.49304531  0.74749853  0.73615294 -0.67493786
#   -0.91527589 -0.23109729 -0.94478629  0.10665929  0.40105933  0.31995853
#    0.06486337  0.70475922  0.75218255]
#  [-3.21068526 -0.6411467   2.47895976  0.97833661 -0.50451212 -1.5247638
#    0.93391177 -1.11517352  0.99709677 -0.74989967 -0.57871947  0.05566699
#    0.31680714  0.13268479  1.10387322]
#  [ 0.06906842  2.10273464  0.34839463 -1.0878455   1.66841986 -0.33851578
#    1.39409968 -0.25644964  0.75819431  0.71406147 -0.52969415 -0.17262388
#    0.30223712  0.01734282  0.22900222]]

# %%
scaled_data.shape
# Out:
# (1000, 1041)

# %%
type(data_pca)
# Out:
# numpy.ndarray

# %%
data_pca.ndim
# Out:
# 2

# %%
data_pca.shape
# Out:
# (1000, 15)

# %% [markdown]
# # Handling imbalanced data

# %%
data.age.value_counts(True)
# Out:
# age
# -0.215870    0.146
#  1.518025    0.134
# -1.516291    0.133
#  0.217604    0.125
#  1.084551    0.119
# -1.082817    0.117
# -0.649344    0.113
#  0.651077    0.113
# Name: proportion, dtype: float64

# %%
data.shape
# Out:
# (1000, 1025)

# %%
print(data.columns)
# Out:
# Index(['age', 'study_hours_per_day', 'social_media_hours', 'netflix_hours',
#        'attendance_percentage', 'sleep_hours', 'exercise_frequency',
#        'mental_health_rating', 'exam_score', 'student_id_S1000',
#        ...
#        'diet_quality_Good', 'diet_quality_Poor',
#        'parental_education_level_Bachelor',
#        'parental_education_level_High School',
#        'parental_education_level_Master', 'internet_quality_Average',
#        'internet_quality_Good', 'internet_quality_Poor',
#        'extracurricular_participation_No',
#        'extracurricular_participation_Yes'],
#       dtype='object', length=1025)

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.decomposition import PCA
from imblearn.over_sampling import SMOTE
import matplotlib.pyplot as plt

data.fillna(data.mean(numeric_only=True), inplace=True)

cat_features = [feature for feature in data.columns if data[feature].dtype == 'O']
numeric_features = [feature for feature in data.columns if data[feature].dtype != 'O']

data = pd.get_dummies(data, columns=cat_features)

scaler = StandardScaler()
data[numeric_features] = scaler.fit_transform(data[numeric_features].values)

if data['sleep_hours'].dtype != 'int64' and data['sleep_hours'].dtype != 'bool':
  data['sleep_hours'] = (data['sleep_hours'] > 0.5).astype(int)

X = data.drop(columns=['sleep_hours'])  
y = data['sleep_hours'] 
if y.dtype == 'O':
    le = LabelEncoder()
    y = le.fit_transform(y)

print(X.shape, y.shape)

smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)

data_resampled = pd.concat([pd.DataFrame(X_resampled, columns=X.columns), pd.DataFrame(y_resampled, columns=['sleep_hours'])], axis=1)
data_resampled.head()
# Out:
# (1000, 1024) (1000,)
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
#         age  study_hours_per_day  social_media_hours  netflix_hours  \
# 0  1.084551            -2.418068           -1.114064      -0.669750
# 1 -0.215870             2.281707            0.251315       0.446965
# 2  0.217604            -1.464491            0.507324      -0.483631
# 3  1.084551            -1.736942            1.190013      -0.762810
# 4 -0.649344             0.987566            1.616694      -1.228108
#
#    attendance_percentage  exercise_frequency  mental_health_rating  \
# 0               0.092426            1.461166              0.900186
# 1               1.401696            1.461166              0.900186
# ...

# %%
data_resampled['exam_score'].value_counts(normalize=True)
# Out:
# exam_score
#  1.800846    0.037846
#  0.669338    0.005095
#  0.065077    0.005095
#  0.260573    0.005095
# -0.237054    0.005095
#                ...
# -0.083027    0.000728
# -1.700314    0.000728
#  0.011759    0.000728
# -1.350790    0.000728
#  1.537921    0.000728
# Name: proportion, Length: 850, dtype: float64

# %%
data_resampled.shape
# Out:
# (1374, 1025)

# %% [markdown]
# # Undersampling

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.decomposition import PCA
from imblearn.over_sampling import SMOTE
import matplotlib.pyplot as plt

data.fillna(data.mean(numeric_only=True), inplace=True)

cat_features = [feature for feature in data.columns if data[feature].dtype == 'O']
numeric_features = [feature for feature in data.columns if data[feature].dtype != 'O']

data = pd.get_dummies(data, columns=cat_features)

scaler = StandardScaler()
data[numeric_features] = scaler.fit_transform(data[numeric_features].values)

if data['exam_score'].dtype != 'int64' and data['exam_score'].dtype != 'bool':
    data['exam_score'] = (data['exam_score'] > 0.5).astype(int)

X = data.drop(columns=['exam_score']) 
y = data['exam_score']  


if y.dtype == 'O':
    le = LabelEncoder()
    y = le.fit_transform(y)

print(X.shape, y.shape)

from imblearn.under_sampling import RandomUnderSampler

rus = RandomUnderSampler()
X_resampled, y_resampled = rus.fit_resample(X, y)

data_resampled = pd.concat([pd.DataFrame(X_resampled, columns=X.columns), pd.DataFrame(y_resampled, columns=['exam_score'])], axis=1)
data_resampled.head()
# Out:
# (1000, 1024) (1000,)
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\base.py:484: FutureWarning: `BaseEstimator._check_n_features` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_n_features` instead.
#   warnings.warn(
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\base.py:493: FutureWarning: `BaseEstimator._check_feature_names` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_feature_names` instead.
#   warnings.warn(
#           age  study_hours_per_day  social_media_hours  netflix_hours  \
# 521  1.084551            -0.034124           -0.346038      -0.390571
# 528 -1.082817             0.238326            0.763332       1.284502
# 420 -1.082817             0.170214            0.336651       2.122039
# 744 -0.649344            -0.170350           -1.540745       1.656740
# 342 -0.649344            -0.851477           -0.346038      -0.018333
#
# ...

# %%
data_resampled['exam_score'].value_counts(normalize=True)
# Out:
# exam_score
# 0    0.5
# 1    0.5
# Name: proportion, dtype: float64

# %%
data_resampled.shape
# Out:
# (602, 1025)

# %% [markdown]
# # Target Encoder

# %%
print(data.columns)
# Out:
# Index(['age', 'study_hours_per_day', 'social_media_hours', 'netflix_hours',
#        'attendance_percentage', 'sleep_hours', 'exercise_frequency',
#        'mental_health_rating', 'exam_score', 'student_id_S1000',
#        ...
#        'diet_quality_Good', 'diet_quality_Poor',
#        'parental_education_level_Bachelor',
#        'parental_education_level_High School',
#        'parental_education_level_Master', 'internet_quality_Average',
#        'internet_quality_Good', 'internet_quality_Poor',
#        'extracurricular_participation_No',
#        'extracurricular_participation_Yes'],
#       dtype='object', length=1025)

# %%
import pandas as pd
import category_encoders as ce


print(data.head())

categorical_column = 'age'  
target_column = 'exam_score' 

target_encoder = ce.TargetEncoder(cols=[categorical_column])

data[categorical_column] = target_encoder.fit_transform(data[categorical_column], data[target_column])

print(data.head())
# Out:
#   student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0      S1000   23  Female                  0.0                 1.2
# 1      S1001   20  Female                  6.9                 2.8
# 2      S1002   21    Male                  1.4                 3.1
# 3      S1003   23  Female                  1.0                 3.9
# 4      S1004   19  Female                  5.0                 4.4
#
#    netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0            1.1            No                   85.0          8.0
# 1            2.3            No                   97.3          4.6
# 2            1.3            No                   94.8          8.0
# 3            1.0            No                   71.0          9.2
# 4            0.5            No                   90.9          4.9
#
#   diet_quality  exercise_frequency parental_education_level internet_quality  \
# 0         Fair                   6                   Master          Average
# ...

# %% [markdown]
# # Splitting Data

# %%
column_name = 'sleep_hours'
if column_name in data.columns:
    X = data.drop(column_name, axis=1)
    y = data[column_name]
else:
    print(f"Column '{column_name}' not found!")

# %%
from sklearn.model_selection import train_test_split

X = data.drop('sleep_hours', axis=1)
y = data['sleep_hours']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((700, 1024), (300, 1024), (700,), (300,))
